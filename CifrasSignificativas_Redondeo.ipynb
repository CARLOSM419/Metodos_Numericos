# %% [markdown]
# <a href="https://colab.research.google.com/github/CARLOSM419/Metodos_Numericos/blob/main/CifrasSignificativas_Redondeo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio 1 : Cifras Significativas y redondeo
# Objetivo : analizar el efecto del redondeo
#
# 04/02/2026

# %%
import numpy as np # Importa la librería NumPy (aunque en este código no se utiliza)
# Asigna a la variable x un número decimal con muchos dígitos
x = 3.1415926535
 # Redondea el número a 2 decimales y lo imprime (resultado: 3.14)
print(round(x,2))
print(round(x,4))# Redondea el número a 4 decimales y lo imprime (resultado: 3.1416)
print(round(x,6))# Redondea el número a 6 decimales y lo imprime (resultado: 3.141593)
# Out:
# 3.14
# 3.1416
# 3.141593
